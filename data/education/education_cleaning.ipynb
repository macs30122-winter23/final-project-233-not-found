# %%
import pandas as pd
import os
import glob
import re

# %%
# Access all education attainment csv and combine into one
path = os.getcwd()
csv_files = glob.glob(os.path.join(path, "*.csv"))

dfs = []
# loop over the list of csv files
for f in csv_files:
    filename = f.split("\\")[-1]
    year = re.findall(r"\d+", filename)[-1]

    # read the csv file
    df = pd.read_csv(f)
    df = df.T
    df['year'] = year
    dfs.append(df)

df = pd.concat(dfs)

# %%
m_ind = [5, 8, 9]
f_ind = [46, 49, 50]

def get_indexes(ind):
    ''' 
    Get the column indexes to retreve data for male and female education attainment
    
    Input (lst): Initial list of indexes, either male or female 
    
    Return: a list of column indexes
    '''

    indexes = ind.copy()
    for i in range(1, 5):
        index = []
        for j in ind:
            index.append(j+8*i)
        indexes.extend(index)

    return indexes

# %%
m_indexes = get_indexes(m_ind)
m_indexes.insert(0, 1)
m_indexes.append(-1)

# %%
f_indexes = get_indexes(f_ind)
f_indexes.insert(0, 42)
f_indexes.append(-1)

# %%
female_df = df.iloc[:, f_indexes]
male_df = df.iloc[:, m_indexes]

# %%
df_f_test = female_df
df_m_test = male_df

# %%
df_f_test = df_f_test[df_f_test.index.str.contains('Estimate')]
df_m_test = df_m_test[df_m_test.index.str.contains('Estimate')]

# %%
def remove_after_exclamation(s):
    ''' 
    Remove the !! in each row name, i.e., change Alabama!!Estimate to Alabama Estimate
    
    '''
    return re.sub('!.+', '', s)

# %%
df_f_test = df_f_test.apply(lambda x: x.str.replace(',', "").astype(int), axis=1)
df_m_test = df_m_test.apply(lambda x: x.str.replace(',', "").astype(int), axis=1)

# %%
f_header = female_df.iloc[0, :]
df_f_test.columns = f_header
df_f_test.head()
# Out:
# Label (Grouping)          Female:  \
# Alabama!!Estimate         1924729
# Alaska!!Estimate           257346
# Arizona!!Estimate         2461657
# Arkansas!!Estimate        1146736
# California!!Estimate     14418147
#
# Label (Grouping)                  High school graduate, GED, or alternative  \
# Alabama!!Estimate                                                 64909
# Alaska!!Estimate                                                  10911
# Arizona!!Estimate                                                 86021
# Arkansas!!Estimate                                                39434
# California!!Estimate                                             511666
#
# Label (Grouping)                  Bachelor's degree  \
# Alabama!!Estimate                             18799
# Alaska!!Estimate                               2585
# Arizona!!Estimate                             21024
# Arkansas!!Estimate                             9264
# California!!Estimate                         181329
#
# Label (Grouping)                  Graduate or professional degree  \
# Alabama!!Estimate                                             861
# Alaska!!Estimate                                              149
# Arizona!!Estimate                                            1025
# Arkansas!!Estimate                                            611
# California!!Estimate                                        11167
#
# Label (Grouping)                  High school graduate, GED, or alternative  \
# Alabama!!Estimate                                                 71356
# Alaska!!Estimate                                                  11713
# Arizona!!Estimate                                                 91490
# Arkansas!!Estimate                                                51024
# California!!Estimate                                             505996
#
# Label (Grouping)                  Bachelor's degree  \
# Alabama!!Estimate                             60688
# Alaska!!Estimate                              11574
# Arizona!!Estimate                             84819
# Arkansas!!Estimate                            31156
# California!!Estimate                         648272
#
# Label (Grouping)                  Graduate or professional degree  \
# Alabama!!Estimate                                           27274
# Alaska!!Estimate                                             3914
# Arizona!!Estimate                                           31847
# Arkansas!!Estimate                                          16241
# California!!Estimate                                       264850
#
# Label (Grouping)                  High school graduate, GED, or alternative  \
# Alabama!!Estimate                                                 82644
# Alaska!!Estimate                                                   9840
# Arizona!!Estimate                                                 88814
# Arkansas!!Estimate                                                56426
# California!!Estimate                                             470695
#
# Label (Grouping)                  Bachelor's degree  \
# Alabama!!Estimate                             54489
# Alaska!!Estimate                              10513
# Arizona!!Estimate                             77234
# Arkansas!!Estimate                            33851
# California!!Estimate                         556044
#
# Label (Grouping)                  Graduate or professional degree  \
# Alabama!!Estimate                                           32133
# Alaska!!Estimate                                             5735
# Arizona!!Estimate                                           41957
# Arkansas!!Estimate                                          13288
# California!!Estimate                                       319893
#
# Label (Grouping)                  High school graduate, GED, or alternative  \
# Alabama!!Estimate                                                214381
# Alaska!!Estimate                                                  26418
# Arizona!!Estimate                                                189800
# Arkansas!!Estimate                                               140476
# California!!Estimate                                             955290
#
# Label (Grouping)                  Bachelor's degree  \
# Alabama!!Estimate                             91312
# Alaska!!Estimate                              16008
# Arizona!!Estimate                            132571
# Arkansas!!Estimate                            49234
# California!!Estimate                         897584
#
# Label (Grouping)                  Graduate or professional degree  \
# Alabama!!Estimate                                           59346
# Alaska!!Estimate                                             9987
# Arizona!!Estimate                                           80621
# Arkansas!!Estimate                                          29697
# California!!Estimate                                       530535
#
# Label (Grouping)                  High school graduate, GED, or alternative  \
# Alabama!!Estimate                                                147533
# Alaska!!Estimate                                                   7653
# Arizona!!Estimate                                                166062
# Arkansas!!Estimate                                               100553
# California!!Estimate                                             654063
#
# Label (Grouping)                  Bachelor's degree  \
# Alabama!!Estimate                             28493
# Alaska!!Estimate                               4094
# Arizona!!Estimate                             62661
# Arkansas!!Estimate                            17035
# California!!Estimate                         340495
#
# Label (Grouping)                  Graduate or professional degree  2011
# Alabama!!Estimate                                           21819  2011
# Alaska!!Estimate                                             2612  2011
# Arizona!!Estimate                                           37865  2011
# Arkansas!!Estimate                                          13153  2011
# California!!Estimate                                       197228  2011

# %%
m_header = male_df.iloc[0, :]
df_m_test.columns = m_header
df_m_test.head()
# Out:
# Label (Grouping)          Male:  \
# Alabama!!Estimate       1753623
# Alaska!!Estimate         277149
# Arizona!!Estimate       2396824
# Arkansas!!Estimate      1080057
# California!!Estimate   14006329
#
# Label (Grouping)                  High school graduate, GED, or alternative  \
# Alabama!!Estimate                                                 76434
# Alaska!!Estimate                                                  16955
# Arizona!!Estimate                                                111295
# Arkansas!!Estimate                                                53151
# California!!Estimate                                             636395
#
# Label (Grouping)                  Bachelor's degree  \
# Alabama!!Estimate                             13223
# Alaska!!Estimate                               1297
# Arizona!!Estimate                             18379
# Arkansas!!Estimate                             6752
# California!!Estimate                         123828
#
# Label (Grouping)                  Graduate or professional degree  \
# Alabama!!Estimate                                             418
# Alaska!!Estimate                                              198
# Arizona!!Estimate                                             958
# Arkansas!!Estimate                                           1138
# California!!Estimate                                         9922
#
# Label (Grouping)                  High school graduate, GED, or alternative  \
# Alabama!!Estimate                                                 92241
# Alaska!!Estimate                                                  18625
# Arizona!!Estimate                                                114173
# Arkansas!!Estimate                                                68710
# California!!Estimate                                             682654
#
# Label (Grouping)                  Bachelor's degree  \
# Alabama!!Estimate                             44248
# Alaska!!Estimate                               8145
# Arizona!!Estimate                             77159
# Arkansas!!Estimate                            29781
# California!!Estimate                         541289
#
# Label (Grouping)                  Graduate or professional degree  \
# Alabama!!Estimate                                           18932
# Alaska!!Estimate                                             1920
# Arizona!!Estimate                                           26501
# Arkansas!!Estimate                                           9581
# California!!Estimate                                       196639
#
# Label (Grouping)                  High school graduate, GED, or alternative  \
# Alabama!!Estimate                                                 89687
# Alaska!!Estimate                                                  15220
# Arizona!!Estimate                                                100965
# Arkansas!!Estimate                                                68945
# California!!Estimate                                             561569
#
# Label (Grouping)                  Bachelor's degree  \
# Alabama!!Estimate                             43725
# Alaska!!Estimate                               7147
# Arizona!!Estimate                             73019
# Arkansas!!Estimate                            26103
# California!!Estimate                         495083
#
# Label (Grouping)                  Graduate or professional degree  \
# Alabama!!Estimate                                           21042
# Alaska!!Estimate                                             5071
# Arizona!!Estimate                                           34735
# Arkansas!!Estimate                                          11717
# California!!Estimate                                       303495
#
# Label (Grouping)                  High school graduate, GED, or alternative  \
# Alabama!!Estimate                                                203297
# Alaska!!Estimate                                                  31704
# Arizona!!Estimate                                                186241
# Arkansas!!Estimate                                               142494
# California!!Estimate                                             954170
#
# Label (Grouping)                  Bachelor's degree  \
# Alabama!!Estimate                             84960
# Alaska!!Estimate                              15450
# Arizona!!Estimate                            136595
# Arkansas!!Estimate                            46910
# California!!Estimate                         872195
#
# Label (Grouping)                  Graduate or professional degree  \
# Alabama!!Estimate                                           55710
# Alaska!!Estimate                                            10316
# Arizona!!Estimate                                           84341
# Arkansas!!Estimate                                          29195
# California!!Estimate                                       584038
#
# Label (Grouping)                  High school graduate, GED, or alternative  \
# Alabama!!Estimate                                                 84311
# Alaska!!Estimate                                                   7200
# Arizona!!Estimate                                                 99042
# Arkansas!!Estimate                                                64588
# California!!Estimate                                             366557
#
# Label (Grouping)                  Bachelor's degree  \
# Alabama!!Estimate                             35573
# Alaska!!Estimate                               4222
# Arizona!!Estimate                             75488
# Arkansas!!Estimate                            20833
# California!!Estimate                         346460
#
# Label (Grouping)                  Graduate or professional degree  2011
# Alabama!!Estimate                                           30788  2011
# Alaska!!Estimate                                             3753  2011
# Arizona!!Estimate                                           61785  2011
# Arkansas!!Estimate                                          17045  2011
# California!!Estimate                                       312220  2011

# %%
df_f_groupby = df_f_test.groupby(level=0, axis=1).sum()
df_m_groupby = df_m_test.groupby(level=0, axis=1).sum()

# %%
df_f_groupby.shape, df_m_groupby.shape
# Out:
# ((520, 5), (520, 5))

# %%
df_f_groupby.iloc[:, 2:]
# Out:
# Label (Grouping)                     Bachelor's degree  \
# Alabama!!Estimate                               253781
# Alaska!!Estimate                                 44774
# Arizona!!Estimate                               378309
# Arkansas!!Estimate                              140540
# California!!Estimate                           2623724
# ...                                                ...
# Washington!!Estimate                            647285
# West Virginia!!Estimate                          94536
# Wisconsin!!Estimate                             470096
# Wyoming!!Estimate                                38757
# Puerto Rico!!Estimate                           295391
#
# Label (Grouping)                     Graduate or professional degree  \
# Alabama!!Estimate                                             141433
# Alaska!!Estimate                                               22397
# Arizona!!Estimate                                             193315
# Arkansas!!Estimate                                             72990
# California!!Estimate                                         1323673
# ...                                                              ...
# Washington!!Estimate                                          369016
# West Virginia!!Estimate                                        62724
# Wisconsin!!Estimate                                           227887
# Wyoming!!Estimate                                              20850
# Puerto Rico!!Estimate                                         108763
#
# Label (Grouping)                     High school graduate, GED, or alternative
# Alabama!!Estimate                                                   580823
# Alaska!!Estimate                                                     66535
# Arizona!!Estimate                                                   622187
# Arkansas!!Estimate                                                  387913
# California!!Estimate                                               3097710
# ...                                                                    ...
# Washington!!Estimate                                                639419
# West Virginia!!Estimate                                             274374
# Wisconsin!!Estimate                                                 661076
# Wyoming!!Estimate                                                    57739
# Puerto Rico!!Estimate                                               355913
#
# [520 rows x 3 columns]

# %%
df_edu = pd.DataFrame(df_f_groupby.iloc[:, 2:5].sum(axis=1)/ df_m_groupby.iloc[:, 2:5].sum(axis=1))
df_edu.head()
# Out:
#                              0
# Alabama!!Estimate     1.091045
# Alaska!!Estimate      0.908187
# Arizona!!Estimate     0.994282
# Arkansas!!Estimate    1.007538
# California!!Estimate  1.008387

# %%
df_edu['year'] = df_f_groupby['2011']
df_edu.columns = ['education','year']
df_edu.head()
# Out:
#                       education  year
# Alabama!!Estimate      1.091045  2011
# Alaska!!Estimate       0.908187  2011
# Arizona!!Estimate      0.994282  2011
# Arkansas!!Estimate     1.007538  2011
# California!!Estimate   1.008387  2011

# %%
# clean the format of state names
df_edu.index = df_edu.index.map(remove_after_exclamation)

# %%
# convert index to a column state
df_edu.reset_index(inplace=True)
df_edu = df_edu.rename(columns={'index': "state"})

# %%
df_edu.columns
# Out:
# Index(['state', 'education', 'year'], dtype='object')

# %%
state_names = ["Alaska", "Alabama", "Arkansas", "Arizona", "California", "Colorado", 
               "Connecticut", "Delaware", "Florida", "Georgia",  "Hawaii", 
               "Iowa", "Idaho", "Illinois", "Indiana", "Kansas", "Kentucky", "Louisiana", "Massachusetts", "Maryland", 
               "Maine", "Michigan", "Minnesota", "Missouri", "Mississippi", "Montana", "North Carolina", "North Dakota", 
               "Nebraska", "New Hampshire", "New Jersey", "New Mexico", "Nevada", "New York", "Ohio", "Oklahoma", 
               "Oregon", "Pennsylvania", "Rhode Island", "South Carolina", "South Dakota", "Tennessee", 
               "Texas", "Utah", "Virginia", "Vermont", "Washington", "Wisconsin", "West Virginia", 
               "Wyoming"]

# %%
# select 50 major states
df_edu = df_edu[df_edu['state'].isin(state_names)]

# %%
df_edu.reset_index(drop=True, inplace=True)

# %%
df_edu
# Out:
#              state  education  year
# 0          Alabama   1.091045  2011
# 1           Alaska   0.908187  2011
# 2          Arizona   0.994282  2011
# 3         Arkansas   1.007538  2011
# 4       California   1.008387  2011
# ..             ...        ...   ...
# 495       Virginia   1.031591  2020
# 496     Washington   0.985292  2020
# 497  West Virginia   1.006788  2020
# 498      Wisconsin   1.032818  2020
# 499        Wyoming   0.913917  2020
#
# [500 rows x 3 columns]

# %%
import seaborn as sns

# %%
df_edu.to_csv(r'..\..\cleaned_data\clean_education.csv', encoding='utf-8', index=False)
