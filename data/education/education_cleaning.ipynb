# %%
import pandas as pd
import os
import glob
import re

# %%
# Access all education attainment csv and combine into one
path = os.getcwd()
csv_files = glob.glob(os.path.join(path, "*.csv"))

dfs = []
# loop over the list of csv files
for f in csv_files:
    filename = f.split("\\")[-1]
    year = re.findall(r"\d+", filename)[-1]

    # read the csv file
    df = pd.read_csv(f)
    df = df.T
    df['year'] = year
    dfs.append(df)

df = pd.concat(dfs)

# %%
m_ind = [5, 8, 9]
f_ind = [46, 49, 50]

def get_indexes(ind):
    ''' 
    Get the column indexes to retreve data for male and female education attainment
    
    Input (lst): Initial list of indexes, either male or female 
    
    Return: a list of column indexes
    '''

    indexes = ind.copy()
    for i in range(1, 5):
        index = []
        for j in ind:
            index.append(j+8*i)
        indexes.extend(index)

    return indexes

# %%
m_indexes = get_indexes(m_ind)
m_indexes.insert(0, 1)
m_indexes.append(-1)

# %%
f_indexes = get_indexes(f_ind)
f_indexes.insert(0, 42)
f_indexes.append(-1)

# %%
female_df = df.iloc[:, f_indexes]
male_df = df.iloc[:, m_indexes]

# %%
df_f_test = female_df
df_m_test = male_df

# %%
df_f_test = df_f_test[df_f_test.index.str.contains('Estimate')]
df_m_test = df_m_test[df_m_test.index.str.contains('Estimate')]

# %%
def remove_after_exclamation(s):
    ''' 
    Remove the !! in each row name, i.e., change Alabama!!Estimate to Alabama Estimate
    
    '''
    return re.sub('!.+', '', s)

# %%
df_f_test = df_f_test.apply(lambda x: x.str.replace(',', "").astype(int), axis=1)
df_m_test = df_m_test.apply(lambda x: x.str.replace(',', "").astype(int), axis=1)

# %%
f_header = female_df.iloc[0, :]
df_f_test.columns = f_header
df_f_test.head()
# Out:
# Label (Grouping)          Female:  \
# Alabama!!Estimate         1980784
# Alaska!!Estimate           262899
# Arizona!!Estimate         2728146
# Arkansas!!Estimate        1181838
# California!!Estimate     15461706
#
# Label (Grouping)                  High school graduate (includes equivalency)  \
# Alabama!!Estimate                                                 70944
# Alaska!!Estimate                                                  10444
# Arizona!!Estimate                                                104771
# Arkansas!!Estimate                                                44810
# California!!Estimate                                             515217
#
# Label (Grouping)                  Bachelor's degree  \
# Alabama!!Estimate                             18343
# Alaska!!Estimate                               2191
# Arizona!!Estimate                             26016
# Arkansas!!Estimate                            12489
# California!!Estimate                         217370
#
# Label (Grouping)                  Graduate or professional degree  \
# Alabama!!Estimate                                             832
# Alaska!!Estimate                                              182
# Arizona!!Estimate                                            2542
# Arkansas!!Estimate                                           1193
# California!!Estimate                                        14842
#
# Label (Grouping)                  High school graduate (includes equivalency)  \
# Alabama!!Estimate                                                 82245
# Alaska!!Estimate                                                  11931
# Arizona!!Estimate                                                100451
# Arkansas!!Estimate                                                49590
# California!!Estimate                                             560087
#
# Label (Grouping)                  Bachelor's degree  \
# Alabama!!Estimate                             64862
# Alaska!!Estimate                              11120
# Arizona!!Estimate                            106200
# Arkansas!!Estimate                            38666
# California!!Estimate                         810562
#
# Label (Grouping)                  Graduate or professional degree  \
# Alabama!!Estimate                                           28408
# Alaska!!Estimate                                             5251
# Arizona!!Estimate                                           41646
# Arkansas!!Estimate                                          19055
# California!!Estimate                                       357159
#
# Label (Grouping)                  High school graduate (includes equivalency)  \
# Alabama!!Estimate                                                 71769
# Alaska!!Estimate                                                   9132
# Arizona!!Estimate                                                 85225
# Arkansas!!Estimate                                                49062
# California!!Estimate                                             477879
#
# Label (Grouping)                  Bachelor's degree  \
# Alabama!!Estimate                             60320
# Alaska!!Estimate                              11242
# Arizona!!Estimate                             93346
# Arkansas!!Estimate                            34936
# California!!Estimate                         609460
#
# Label (Grouping)                  Graduate or professional degree  \
# Alabama!!Estimate                                           37318
# Alaska!!Estimate                                             6728
# Arizona!!Estimate                                           52804
# Arkansas!!Estimate                                          21323
# California!!Estimate                                       404584
#
# Label (Grouping)                  High school graduate (includes equivalency)  \
# Alabama!!Estimate                                                196065
# Alaska!!Estimate                                                  21607
# Arizona!!Estimate                                                196877
# Arkansas!!Estimate                                               125761
# California!!Estimate                                             999730
#
# Label (Grouping)                  Bachelor's degree  \
# Alabama!!Estimate                            115011
# Alaska!!Estimate                              17693
# Arizona!!Estimate                            153462
# Arkansas!!Estimate                            57148
# California!!Estimate                        1007824
#
# Label (Grouping)                  Graduate or professional degree  \
# Alabama!!Estimate                                           69283
# Alaska!!Estimate                                            11123
# Arizona!!Estimate                                           96966
# Arkansas!!Estimate                                          34885
# California!!Estimate                                       608985
#
# Label (Grouping)                  High school graduate (includes equivalency)  \
# Alabama!!Estimate                                                170092
# Alaska!!Estimate                                                   9791
# Arizona!!Estimate                                                189591
# Arkansas!!Estimate                                               104462
# California!!Estimate                                             698818
#
# Label (Grouping)                  Bachelor's degree  \
# Alabama!!Estimate                             45244
# Alaska!!Estimate                               7299
# Arizona!!Estimate                             88540
# Arkansas!!Estimate                            28651
# California!!Estimate                         495572
#
# Label (Grouping)                  Graduate or professional degree  2018
# Alabama!!Estimate                                           35396  2018
# Alaska!!Estimate                                             4844  2018
# Arizona!!Estimate                                           69086  2018
# Arkansas!!Estimate                                          18350  2018
# California!!Estimate                                       319610  2018

# %%
m_header = male_df.iloc[0, :]
df_m_test.columns = m_header
df_m_test.head()
# Out:
# Label (Grouping)          Male:  \
# Alabama!!Estimate       1799902
# Alaska!!Estimate         291715
# Arizona!!Estimate       2655396
# Arkansas!!Estimate      1114008
# California!!Estimate   15017561
#
# Label (Grouping)                  High school graduate (includes equivalency)  \
# Alabama!!Estimate                                                 90367
# Alaska!!Estimate                                                  17448
# Arizona!!Estimate                                                121360
# Arkansas!!Estimate                                                53799
# California!!Estimate                                             658875
#
# Label (Grouping)                  Bachelor's degree  \
# Alabama!!Estimate                             11509
# Alaska!!Estimate                               2406
# Arizona!!Estimate                             21091
# Arkansas!!Estimate                             8308
# California!!Estimate                         158991
#
# Label (Grouping)                  Graduate or professional degree  \
# Alabama!!Estimate                                             523
# Alaska!!Estimate                                                0
# Arizona!!Estimate                                            1513
# Arkansas!!Estimate                                            591
# California!!Estimate                                        11825
#
# Label (Grouping)                  High school graduate (includes equivalency)  \
# Alabama!!Estimate                                                 92048
# Alaska!!Estimate                                                  22293
# Arizona!!Estimate                                                135477
# Arkansas!!Estimate                                                72454
# California!!Estimate                                             742824
#
# Label (Grouping)                  Bachelor's degree  \
# Alabama!!Estimate                             55678
# Alaska!!Estimate                               8485
# Arizona!!Estimate                             94904
# Arkansas!!Estimate                            32389
# California!!Estimate                         730435
#
# Label (Grouping)                  Graduate or professional degree  \
# Alabama!!Estimate                                           18900
# Alaska!!Estimate                                             3242
# Arizona!!Estimate                                           32449
# Arkansas!!Estimate                                          11905
# California!!Estimate                                       283779
#
# Label (Grouping)                  High school graduate (includes equivalency)  \
# Alabama!!Estimate                                                 93912
# Alaska!!Estimate                                                  16983
# Arizona!!Estimate                                                103217
# Arkansas!!Estimate                                                62312
# California!!Estimate                                             583043
#
# Label (Grouping)                  Bachelor's degree  \
# Alabama!!Estimate                             44339
# Alaska!!Estimate                               8592
# Arizona!!Estimate                             77701
# Arkansas!!Estimate                            29445
# California!!Estimate                         551990
#
# Label (Grouping)                  Graduate or professional degree  \
# Alabama!!Estimate                                           24387
# Alaska!!Estimate                                             4459
# Arizona!!Estimate                                           45666
# Arkansas!!Estimate                                          14935
# California!!Estimate                                       343902
#
# Label (Grouping)                  High school graduate (includes equivalency)  \
# Alabama!!Estimate                                                220514
# Alaska!!Estimate                                                  30842
# Arizona!!Estimate                                                202546
# Arkansas!!Estimate                                               145250
# California!!Estimate                                            1049396
#
# Label (Grouping)                  Bachelor's degree  \
# Alabama!!Estimate                             91475
# Alaska!!Estimate                              15083
# Arizona!!Estimate                            143868
# Arkansas!!Estimate                            48547
# California!!Estimate                         930440
#
# Label (Grouping)                  Graduate or professional degree  \
# Alabama!!Estimate                                           57247
# Alaska!!Estimate                                            10293
# Arizona!!Estimate                                           91055
# Arkansas!!Estimate                                          25729
# California!!Estimate                                       612638
#
# Label (Grouping)                  High school graduate (includes equivalency)  \
# Alabama!!Estimate                                                103337
# Alaska!!Estimate                                                  10553
# Arizona!!Estimate                                                123109
# Arkansas!!Estimate                                                74394
# California!!Estimate                                             429405
#
# Label (Grouping)                  Bachelor's degree  \
# Alabama!!Estimate                             51090
# Alaska!!Estimate                               6930
# Arizona!!Estimate                            105041
# Arkansas!!Estimate                            31512
# California!!Estimate                         480166
#
# Label (Grouping)                  Graduate or professional degree  2018
# Alabama!!Estimate                                           45746  2018
# Alaska!!Estimate                                             6300  2018
# Arizona!!Estimate                                           90358  2018
# Arkansas!!Estimate                                          22638  2018
# California!!Estimate                                       429141  2018

# %%
df_f_groupby = df_f_test.groupby(level=0, axis=1).sum()
df_m_groupby = df_m_test.groupby(level=0, axis=1).sum()

# %%
df_f_groupby.shape, df_m_groupby.shape
# Out:
# ((520, 5), (520, 5))

# %%
df_f_groupby.iloc[:, 2:]
# Out:
# Label (Grouping)                     Bachelor's degree  \
# Alabama!!Estimate                               303780
# Alaska!!Estimate                                 49545
# Arizona!!Estimate                               467564
# Arkansas!!Estimate                              171890
# California!!Estimate                           3140788
# ...                                                ...
# Washington!!Estimate                            602100
# West Virginia!!Estimate                          92260
# Wisconsin!!Estimate                             443338
# Wyoming!!Estimate                                37061
# Puerto Rico!!Estimate                           297279
#
# Label (Grouping)                     Graduate or professional degree  \
# Alabama!!Estimate                                             171237
# Alaska!!Estimate                                               28128
# Arizona!!Estimate                                             263044
# Arkansas!!Estimate                                             94806
# California!!Estimate                                         1705180
# ...                                                              ...
# Washington!!Estimate                                          330519
# West Virginia!!Estimate                                        58232
# Wisconsin!!Estimate                                           212941
# Wyoming!!Estimate                                              18689
# Puerto Rico!!Estimate                                          96882
#
# Label (Grouping)                     High school graduate (includes equivalency)
# Alabama!!Estimate                                                   591115
# Alaska!!Estimate                                                     62905
# Arizona!!Estimate                                                   676915
# Arkansas!!Estimate                                                  373685
# California!!Estimate                                               3251731
# ...                                                                    ...
# Washington!!Estimate                                                627001
# West Virginia!!Estimate                                             279561
# Wisconsin!!Estimate                                                 678275
# Wyoming!!Estimate                                                    59062
# Puerto Rico!!Estimate                                               364235
#
# [520 rows x 3 columns]

# %%
df_edu = pd.DataFrame(df_f_groupby.iloc[:, 2:5].sum(axis=1)/ df_m_groupby.iloc[:, 2:5].sum(axis=1))
df_edu.head()
# Out:
#                              0
# Alabama!!Estimate     1.064990
# Alaska!!Estimate      0.857659
# Arizona!!Estimate     1.013077
# Arkansas!!Estimate    1.009733
# California!!Estimate  1.012611

# %%
df_edu['year'] = df_f_groupby['2018']
df_edu.columns = ['education','year']
df_edu.head()
# Out:
#                       education  year
# Alabama!!Estimate      1.064990  2018
# Alaska!!Estimate       0.857659  2018
# Arizona!!Estimate      1.013077  2018
# Arkansas!!Estimate     1.009733  2018
# California!!Estimate   1.012611  2018

# %%
# clean the format of state names
df_edu.index = df_edu.index.map(remove_after_exclamation)

# %%
# convert index to a column state
df_edu.reset_index(inplace=True)
df_edu = df_edu.rename(columns={'index': "state"})

# %%
df_edu.columns
# Out:
# Index(['state', 'education', 'year'], dtype='object')

# %%
state_names = ["Alaska", "Alabama", "Arkansas", "Arizona", "California", "Colorado", 
               "Connecticut", "Delaware", "Florida", "Georgia",  "Hawaii", 
               "Iowa", "Idaho", "Illinois", "Indiana", "Kansas", "Kentucky", "Louisiana", "Massachusetts", "Maryland", 
               "Maine", "Michigan", "Minnesota", "Missouri", "Mississippi", "Montana", "North Carolina", "North Dakota", 
               "Nebraska", "New Hampshire", "New Jersey", "New Mexico", "Nevada", "New York", "Ohio", "Oklahoma", 
               "Oregon", "Pennsylvania", "Rhode Island", "South Carolina", "South Dakota", "Tennessee", 
               "Texas", "Utah", "Virginia", "Vermont", "Washington", "Wisconsin", "West Virginia", 
               "Wyoming"]

# %%
# select 50 major states
df_edu = df_edu[df_edu['state'].isin(state_names)]

# %%
df_edu.reset_index(drop=True, inplace=True)

# %%
df_edu
# Out:
#              state  education  year
# 0          Alabama   1.064990  2018
# 1           Alaska   0.857659  2018
# 2          Arizona   1.013077  2018
# 3         Arkansas   1.009733  2018
# 4       California   1.012611  2018
# ..             ...        ...   ...
# 495       Virginia   1.036694  2016
# 496     Washington   0.981606  2016
# 497  West Virginia   1.022023  2016
# 498      Wisconsin   1.034382  2016
# 499        Wyoming   0.905729  2016
#
# [500 rows x 3 columns]

# %%
df_edu.to_csv('clean_education.csv', encoding='utf-8', index=False)
