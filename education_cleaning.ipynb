# %%
import pandas as pd
import os
import glob
import re

# %%
# Access all education attainment csv and combine into one
path = os.getcwd()
csv_files = glob.glob(os.path.join(path, "*.csv"))

dfs = []
# loop over the list of csv files
for f in csv_files:
    filename = f.split("\\")[-1]
    year = re.findall(r"\d+", filename)[-1]

    # read the csv file
    df = pd.read_csv(f)
    df = df.T
    df['year'] = year
    dfs.append(df)

df = pd.concat(dfs)

# %%
m_ind = [5, 8, 9]
f_ind = [46, 49, 50]

def get_indexes(ind):
    ''' 
    Get the column indexes to retreve data for male and female education attainment
    
    Input (lst): Initial list of indexes, either male or female 
    
    Return: a list of column indexes
    '''

    indexes = ind.copy()
    for i in range(1, 5):
        index = []
        for j in ind:
            index.append(j+8*i)
        indexes.extend(index)

    return indexes

# %%
m_indexes = get_indexes(m_ind)
m_indexes.insert(0, 1)
m_indexes.append(-1)

# %%
f_indexes = get_indexes(f_ind)
f_indexes.insert(0, 42)
f_indexes.append(-1)

# %%
female_df = df.iloc[:, f_indexes]
male_df = df.iloc[:, m_indexes]

# %%
df_f_test = female_df
df_m_test = male_df

# %%
df_f_test = df_f_test[df_f_test.index.str.contains('Estimate')]
df_m_test = df_m_test[df_m_test.index.str.contains('Estimate')]

# %%
def remove_after_exclamation(s):
    ''' 
    Remove the !! in each row name, i.e., change Alabama!!Estimate to Alabama Estimate
    
    '''
    return re.sub('!.+', '', s)

# %%
df_f_test = df_f_test.apply(lambda x: x.str.replace(',', "").astype(int), axis=1)
df_m_test = df_m_test.apply(lambda x: x.str.replace(',', "").astype(int), axis=1)

# %%
f_header = female_df.iloc[0, :]
df_f_test.columns = f_header
df_f_test.head()
# Out:
# Label (Grouping)          Female:  \
# Alabama!!Estimate         1992175
# Alaska!!Estimate           263271
# Arizona!!Estimate         2805863
# Arkansas!!Estimate        1190236
# California!!Estimate     15405196
#
# Label (Grouping)                  High school graduate (includes equivalency)  \
# Alabama!!Estimate                                                 69800
# Alaska!!Estimate                                                  11276
# Arizona!!Estimate                                                106396
# Arkansas!!Estimate                                                42558
# California!!Estimate                                             507125
#
# Label (Grouping)                  Bachelor's degree  \
# Alabama!!Estimate                             19768
# Alaska!!Estimate                               2205
# Arizona!!Estimate                             33650
# Arkansas!!Estimate                            13544
# California!!Estimate                         228087
#
# Label (Grouping)                  Graduate or professional degree  \
# Alabama!!Estimate                                            1782
# Alaska!!Estimate                                              163
# Arizona!!Estimate                                            2114
# Arkansas!!Estimate                                            734
# California!!Estimate                                        16832
#
# Label (Grouping)                  High school graduate (includes equivalency)  \
# Alabama!!Estimate                                                 77515
# Alaska!!Estimate                                                  14592
# Arizona!!Estimate                                                103928
# Arkansas!!Estimate                                                52406
# California!!Estimate                                             545062
#
# Label (Grouping)                  Bachelor's degree  \
# Alabama!!Estimate                             70099
# Alaska!!Estimate                              13159
# Arizona!!Estimate                            111405
# Arkansas!!Estimate                            40411
# California!!Estimate                         841760
#
# Label (Grouping)                  Graduate or professional degree  \
# Alabama!!Estimate                                           30935
# Alaska!!Estimate                                             4653
# Arizona!!Estimate                                           43754
# Arkansas!!Estimate                                          18641
# California!!Estimate                                       371150
#
# Label (Grouping)                  High school graduate (includes equivalency)  \
# Alabama!!Estimate                                                 70208
# Alaska!!Estimate                                                   9623
# Arizona!!Estimate                                                 85798
# Arkansas!!Estimate                                                47271
# California!!Estimate                                             457152
#
# Label (Grouping)                  Bachelor's degree  \
# Alabama!!Estimate                             62809
# Alaska!!Estimate                              10790
# Arizona!!Estimate                             94769
# Arkansas!!Estimate                            35915
# California!!Estimate                         623081
#
# Label (Grouping)                  Graduate or professional degree  \
# Alabama!!Estimate                                           39699
# Alaska!!Estimate                                             7329
# Arizona!!Estimate                                           59629
# Arkansas!!Estimate                                          23091
# California!!Estimate                                       427710
#
# Label (Grouping)                  High school graduate (includes equivalency)  \
# Alabama!!Estimate                                                193390
# Alaska!!Estimate                                                  21797
# Arizona!!Estimate                                                195738
# Arkansas!!Estimate                                               124807
# California!!Estimate                                             957760
#
# Label (Grouping)                  Bachelor's degree  \
# Alabama!!Estimate                            109335
# Alaska!!Estimate                              17955
# Arizona!!Estimate                            164064
# Arkansas!!Estimate                            60344
# California!!Estimate                        1009691
#
# Label (Grouping)                  Graduate or professional degree  \
# Alabama!!Estimate                                           71903
# Alaska!!Estimate                                            11658
# Arizona!!Estimate                                          102201
# Arkansas!!Estimate                                          33049
# California!!Estimate                                       620443
#
# Label (Grouping)                  High school graduate (includes equivalency)  \
# Alabama!!Estimate                                                174091
# Alaska!!Estimate                                                  12527
# Arizona!!Estimate                                                191143
# Arkansas!!Estimate                                               109236
# California!!Estimate                                             705859
#
# Label (Grouping)                  Bachelor's degree  \
# Alabama!!Estimate                             51128
# Alaska!!Estimate                               7315
# Arizona!!Estimate                             99812
# Arkansas!!Estimate                            29873
# California!!Estimate                         525932
#
# Label (Grouping)                  Graduate or professional degree  2020
# Alabama!!Estimate                                           39805  2020
# Alaska!!Estimate                                             6054  2020
# Arizona!!Estimate                                           75440  2020
# Arkansas!!Estimate                                          21067  2020
# California!!Estimate                                       342893  2020

# %%
m_header = male_df.iloc[0, :]
df_m_test.columns = m_header
df_m_test.head()
# Out:
# Label (Grouping)          Male:  \
# Alabama!!Estimate       1808099
# Alaska!!Estimate         290360
# Arizona!!Estimate       2728556
# Arkansas!!Estimate      1118805
# California!!Estimate   14984186
#
# Label (Grouping)                  High school graduate (includes equivalency)  \
# Alabama!!Estimate                                                 85209
# Alaska!!Estimate                                                  18420
# Arizona!!Estimate                                                129369
# Arkansas!!Estimate                                                55446
# California!!Estimate                                             657609
#
# Label (Grouping)                  Bachelor's degree  \
# Alabama!!Estimate                             13617
# Alaska!!Estimate                               1765
# Arizona!!Estimate                             25016
# Arkansas!!Estimate                             9618
# California!!Estimate                         169188
#
# Label (Grouping)                  Graduate or professional degree  \
# Alabama!!Estimate                                            1161
# Alaska!!Estimate                                              166
# Arizona!!Estimate                                            1917
# Arkansas!!Estimate                                            701
# California!!Estimate                                        12861
#
# Label (Grouping)                  High school graduate (includes equivalency)  \
# Alabama!!Estimate                                                 98887
# Alaska!!Estimate                                                  22550
# Arizona!!Estimate                                                141838
# Arkansas!!Estimate                                                72873
# California!!Estimate                                             749072
#
# Label (Grouping)                  Bachelor's degree  \
# Alabama!!Estimate                             55780
# Alaska!!Estimate                               9682
# Arizona!!Estimate                             98192
# Arkansas!!Estimate                            32978
# California!!Estimate                         757796
#
# Label (Grouping)                  Graduate or professional degree  \
# Alabama!!Estimate                                           19468
# Alaska!!Estimate                                             2722
# Arizona!!Estimate                                           34858
# Arkansas!!Estimate                                          12752
# California!!Estimate                                       296247
#
# Label (Grouping)                  High school graduate (includes equivalency)  \
# Alabama!!Estimate                                                 87413
# Alaska!!Estimate                                                  14903
# Arizona!!Estimate                                                105988
# Arkansas!!Estimate                                                63631
# California!!Estimate                                             562755
#
# Label (Grouping)                  Bachelor's degree  \
# Alabama!!Estimate                             47428
# Alaska!!Estimate                               8388
# Arizona!!Estimate                             82275
# Arkansas!!Estimate                            29273
# California!!Estimate                         572076
#
# Label (Grouping)                  Graduate or professional degree  \
# Alabama!!Estimate                                           27220
# Alaska!!Estimate                                             5030
# Arizona!!Estimate                                           50733
# Arkansas!!Estimate                                          15411
# California!!Estimate                                       363978
#
# Label (Grouping)                  High school graduate (includes equivalency)  \
# Alabama!!Estimate                                                203895
# Alaska!!Estimate                                                  30500
# Arizona!!Estimate                                                201828
# Arkansas!!Estimate                                               140303
# California!!Estimate                                            1010975
#
# Label (Grouping)                  Bachelor's degree  \
# Alabama!!Estimate                             93706
# Alaska!!Estimate                              14895
# Arizona!!Estimate                            149744
# Arkansas!!Estimate                            47408
# California!!Estimate                         936950
#
# Label (Grouping)                  Graduate or professional degree  \
# Alabama!!Estimate                                           57291
# Alaska!!Estimate                                            10849
# Arizona!!Estimate                                           94893
# Arkansas!!Estimate                                          27380
# California!!Estimate                                       626884
#
# Label (Grouping)                  High school graduate (includes equivalency)  \
# Alabama!!Estimate                                                108943
# Alaska!!Estimate                                                  10994
# Arizona!!Estimate                                                125727
# Arkansas!!Estimate                                                76285
# California!!Estimate                                             442750
#
# Label (Grouping)                  Bachelor's degree  \
# Alabama!!Estimate                             56389
# Alaska!!Estimate                               7977
# Arizona!!Estimate                            110967
# Arkansas!!Estimate                            32446
# California!!Estimate                         497541
#
# Label (Grouping)                  Graduate or professional degree  2020
# Alabama!!Estimate                                           44049  2020
# Alaska!!Estimate                                             6511  2020
# Arizona!!Estimate                                           95962  2020
# Arkansas!!Estimate                                          22656  2020
# California!!Estimate                                       442741  2020

# %%
df_f_groupby = df_f_test.groupby(level=0, axis=1).sum()
df_m_groupby = df_m_test.groupby(level=0, axis=1).sum()

# %%
df_f_groupby.shape, df_m_groupby.shape
# Out:
# ((520, 5), (520, 5))

# %%
df_edu = df_f_groupby.iloc[:, 2:5] / df_m_groupby.iloc[:, 2:6]
df_edu = df_edu.round(3)
# Out:
# Label (Grouping)                     Bachelor's degree  \
# Alabama!!Estimate                                1.173
# Alaska!!Estimate                                 1.204
# Arizona!!Estimate                                1.080
# Arkansas!!Estimate                               1.187
# California!!Estimate                             1.101
# ...                                                ...
# Washington!!Estimate                             1.010
# West Virginia!!Estimate                          1.091
# Wisconsin!!Estimate                              1.157
# Wyoming!!Estimate                                1.104
# Puerto Rico!!Estimate                            1.665
#
# Label (Grouping)                     Graduate or professional degree  \
# Alabama!!Estimate                                              1.234
# Alaska!!Estimate                                               1.181
# Arizona!!Estimate                                              1.017
# Arkansas!!Estimate                                             1.224
# California!!Estimate                                           1.021
# ...                                                              ...
# Washington!!Estimate                                           0.931
# West Virginia!!Estimate                                        1.111
# Wisconsin!!Estimate                                            0.998
# Wyoming!!Estimate                                              1.046
# Puerto Rico!!Estimate                                          1.464
#
# Label (Grouping)                     High school graduate (includes equivalency)
# Alabama!!Estimate                                                    1.001
# Alaska!!Estimate                                                     0.717
# Arizona!!Estimate                                                    0.969
# Arkansas!!Estimate                                                   0.921
# California!!Estimate                                                 0.927
# ...                                                                    ...
# Washington!!Estimate                                                 0.972
# West Virginia!!Estimate                                              0.997
# Wisconsin!!Estimate                                                  0.961
# Wyoming!!Estimate                                                    0.843
# Puerto Rico!!Estimate                                                0.943
#
# [520 rows x 3 columns]

# %%
df_edu['year'] = df_f_groupby['2020']
df_edu.tail()
# Out:
# Label (Grouping)                     Bachelor's degree  \
# Washington!!Estimate                          1.009735
# West Virginia!!Estimate                       1.091435
# Wisconsin!!Estimate                           1.156701
# Wyoming!!Estimate                             1.103849
# Puerto Rico!!Estimate                         1.664651
#
# Label (Grouping)                     Graduate or professional degree  \
# Washington!!Estimate                                        0.931379
# West Virginia!!Estimate                                     1.111455
# Wisconsin!!Estimate                                         0.997529
# Wyoming!!Estimate                                           1.045777
# Puerto Rico!!Estimate                                       1.464186
#
# Label (Grouping)                     High school graduate (includes equivalency)  \
# Washington!!Estimate                                              0.971722
# West Virginia!!Estimate                                           0.997463
# Wisconsin!!Estimate                                               0.960520
# Wyoming!!Estimate                                                 0.843445
# Puerto Rico!!Estimate                                             0.942815
#
# Label (Grouping)         year
# Washington!!Estimate     2011
# West Virginia!!Estimate  2011
# Wisconsin!!Estimate      2011
# Wyoming!!Estimate        2011
# Puerto Rico!!Estimate    2011

# %%
df_edu.index = df_edu.index.map(remove_after_exclamation)

# %%
df_edu.reset_index(inplace=True)
df_edu = df_edu.rename(columns={'index': "state"})

# %%
df_edu.columns
# Out:
# Index(['state', '            Bachelor's degree',
#        '            Graduate or professional degree',
#        '            High school graduate (includes equivalency)', 'year'],
#       dtype='object', name='Label (Grouping)')

# %%
state_names = ["Alaska", "Alabama", "Arkansas", "Arizona", "California", "Colorado", 
               "Connecticut", "Delaware", "Florida", "Georgia",  "Hawaii", 
               "Iowa", "Idaho", "Illinois", "Indiana", "Kansas", "Kentucky", "Louisiana", "Massachusetts", "Maryland", 
               "Maine", "Michigan", "Minnesota", "Missouri", "Mississippi", "Montana", "North Carolina", "North Dakota", 
               "Nebraska", "New Hampshire", "New Jersey", "New Mexico", "Nevada", "New York", "Ohio", "Oklahoma", 
               "Oregon", "Pennsylvania", "Rhode Island", "South Carolina", "South Dakota", "Tennessee", 
               "Texas", "Utah", "Virginia", "Vermont", "Washington", "Wisconsin", "West Virginia", 
               "Wyoming"]

# %%
len(state_names)
# Out:
# 50

# %%
df_edu = df_edu[df_edu['state'].isin(state_names)]

# %%
df_edu.to_csv('education', encoding='utf-8', index=False)
